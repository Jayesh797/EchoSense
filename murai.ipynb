# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import to_categorical
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# 2024-03-30 16:55:19.517085: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-30 16:55:19.517182: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-30 16:55:19.635392: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
Ravdess = "/kaggle/input/ravdess/"
Crema = "/kaggle/input/cremad/AudioWAV/"
Tess = "/kaggle/input/tess-1/TESS Toronto emotional speech set data/"
Savee = "/kaggle/input/saveee/ALL/"
Besd='/kaggle/input/besd-english/BESD/ENGLISH/'

# %%
ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + dir)
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        third_element = part[2]
        if len(part) >= 3:
            third_element = part[2]
            file_emotion.append(third_element)
        else:
    # Handle the case where the filename doesn't match the expected format
    # This could involve skipping the file, logging an error, or other appropriate actions.
    pass

        # third part in each file represents the emotion associated to that file.
        file_emotion.append(third_element)
    
     
#         file_emotion.append(int(part))
        file_path.append(Ravdess + dir + '/' + file)
print(file_emotion)

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Cell In[3], line 18
#     pass
#     ^
# IndentationError: expected an indented block after 'else' statement on line 15

# %%
import os
import pandas as pd

ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []

for directory in ravdess_directory_list:
    # As there are 20 different actors in our previous directory, we need to extract files for each actor.
    actor_files = os.listdir(os.path.join(Ravdess, directory))
    
    for file in actor_files:
        # Splitting the file name to extract emotion
        part = file.split('.')[0].split('-')
        
        if len(part) >= 3:
            third_element = part[2]
            file_emotion.append(third_element)
        else:
            # Handle the case where the filename doesn't match the expected format
            # This could involve skipping the file, logging an error, or other appropriate actions.
            pass

        # Constructing the file path
        file_path.append(os.path.join(Ravdess, directory, file))

# DataFrame for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# DataFrame for path of files
path_df = pd.DataFrame(file_path, columns=['Path'])

# Combining both DataFrames
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# Changing integers to actual emotions
Ravdess_df['Emotions'].replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Emotions                                               Path
# 0       08  /kaggle/input/ravdess/Actor_02/03-01-08-01-01-...
# 1       01  /kaggle/input/ravdess/Actor_02/03-01-01-01-01-...
# 2       07  /kaggle/input/ravdess/Actor_02/03-01-07-02-01-...
# 3       07  /kaggle/input/ravdess/Actor_02/03-01-07-01-01-...
# 4       01  /kaggle/input/ravdess/Actor_02/03-01-01-01-02-...

# %% [markdown]
# ## cremad dataframe

# %%
crema_directory_list = os.listdir(Crema)

file_emotion = []
file_path = []

for file in crema_directory_list:
    # storing file paths
    file_path.append(Crema + file)
    # storing file emotions
    part=file.split('_')
    if part[2] == 'SAD':
        file_emotion.append('sad')
    elif part[2] == 'ANG':
        file_emotion.append('angry')
    elif part[2] == 'DIS':
        file_emotion.append('disgust')
    elif part[2] == 'FEA':
        file_emotion.append('fear')
    elif part[2] == 'HAP':
        file_emotion.append('happy')
    elif part[2] == 'NEU':
        file_emotion.append('neutral')
    else:
        file_emotion.append('Unknown')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Crema_df = pd.concat([emotion_df, path_df], axis=1)
Crema_df.head()
# Out:
#   Emotions                                               Path
# 0  disgust  /kaggle/input/cremad/AudioWAV/1028_TSI_DIS_XX.wav
# 1    happy  /kaggle/input/cremad/AudioWAV/1075_IEO_HAP_LO.wav
# 2    happy  /kaggle/input/cremad/AudioWAV/1084_ITS_HAP_XX.wav
# 3  disgust  /kaggle/input/cremad/AudioWAV/1067_IWW_DIS_XX.wav
# 4  disgust  /kaggle/input/cremad/AudioWAV/1066_TIE_DIS_XX.wav

# %%
besd_directory_list=os.listdir(Besd)
file_emotion=[]
file_path=[]

exclude_values = ['', '5', '39']
for dir in besd_directory_list:
    directories=os.listdir(Besd+dir)
    for file in directories:
        part=file.split(' ')[-1]
        part=part.split('.')[0]
        c=part.split('_')[0].lower()
        
        if c in exclude_values:
            continue
        
        if(c=='disguist'):
            file_emotion.append('disgust')
        elif(c=='angry-5'):
            file_emotion.append('angry')
        elif(c=='sad1'):
            file_emotion.append('sad')
        else:
            file_emotion.append(c)
        file_path.append(Besd + dir + '/' + file)
        
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Besd_df = pd.concat([emotion_df, path_df], axis=1)
Besd_df.head()
# Out:
#   Emotions                                               Path
# 0     fear  /kaggle/input/besd-english/BESD/ENGLISH/FEAR/8...
# 1     fear  /kaggle/input/besd-english/BESD/ENGLISH/FEAR/3...
# 2     fear  /kaggle/input/besd-english/BESD/ENGLISH/FEAR/6...
# 3     fear  /kaggle/input/besd-english/BESD/ENGLISH/FEAR/3...
# 4     fear  /kaggle/input/besd-english/BESD/ENGLISH/FEAR/6...

# %% [markdown]
# ## TESS DATAFRAME

# %%
tess_directory_list = os.listdir(Tess)

file_emotion = []
file_path = []

for dir in tess_directory_list:
    directories = os.listdir(Tess + dir)
    for file in directories:
        part = file.split('.')[0]
        part = part.split('_')[2]
        if part=='ps':
            file_emotion.append('surprise')
        else:
            file_emotion.append(part)
        file_path.append(Tess + dir + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
Tess_df.head()
# Out:
#   Emotions                                               Path
# 0     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 1     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 2     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 3     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 4     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...

# %% [markdown]
# ## SAVEE DATAFRAME

# %%
savee_directory_list = os.listdir(Savee)

file_emotion = []
file_path = []

for file in savee_directory_list:
    file_path.append(Savee + file)
    part = file.split('_')[1]
    ele = part[:-6]
    if ele=='a':
        file_emotion.append('angry')
    elif ele=='d':
        file_emotion.append('disgust')
    elif ele=='f':
        file_emotion.append('fear')
    elif ele=='h':
        file_emotion.append('happy')
    elif ele=='n':
        file_emotion.append('neutral')
    elif ele=='sa':
        file_emotion.append('sad')
    else:
        file_emotion.append('surprise')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Savee_df = pd.concat([emotion_df, path_df], axis=1)
Savee_df.head()
# Out:
#   Emotions                                 Path
# 0    happy  /kaggle/input/saveee/ALL/JE_h09.wav
# 1     fear  /kaggle/input/saveee/ALL/KL_f12.wav
# 2    happy  /kaggle/input/saveee/ALL/DC_h03.wav
# 3  disgust  /kaggle/input/saveee/ALL/DC_d04.wav
# 4    angry  /kaggle/input/saveee/ALL/KL_a14.wav

# %%
data_path = pd.concat([Tess_df,Crema_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                               Path
# 0     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 1     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 2     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 3     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...
# 4     fear  /kaggle/input/tess-1/TESS Toronto emotional sp...

# %%
# plt.title('Count of Emotions', size=16)
# sns.countplot(data_path.Emotions)
# plt.ylabel('Count', size=12)
# plt.xlabel('Emotions', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
# plt.show()


import seaborn as sns
import matplotlib.pyplot as plt

plt.title('Count of Emotions', size=16)
sns.countplot(data=data_path, x='Emotions', order=data_path['Emotions'].value_counts().index)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    plt.plot(data)
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.show()

# def create_waveplot(data, sr, e):
#     plt.figure(figsize=(10, 3))
#     plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
#     librosa.display.waveplot(data, sr=sr)
#     plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

# %%
emotion='fear'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='angry'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='sad'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='happy'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## DATA AUGMENTATION

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=pitch_factor)

# taking any example and checking for techniques.
path = np.array(data_path.Path)[1]
data, sample_rate = librosa.load(path)

# %% [markdown]
# ## SIMPLE AUDIO

# %%
# plt.figure(figsize=(14,4))
# librosa.display.waveplot(y=data, sr=sample_rate)
# Audio(path)

import matplotlib.pyplot as plt

plt.figure(figsize=(14, 4))
plt.plot(data)
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

# %% [markdown]
# ## NOISE INJECTION

# %%
import matplotlib.pyplot as plt

# Assuming you have a function noise() that generates noise based on your audio data
x = noise(data)

plt.figure(figsize=(14, 4))
plt.plot(x)
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.title('Waveform of Generated Noise')
plt.show()

# %% [markdown]
# ## STRECHING

# %%
import matplotlib.pyplot as plt

# Assuming you have a function stretch() that stretches your audio data
x = stretch(data)

plt.figure(figsize=(14, 4))
plt.plot(x)
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.title('Waveform of Stretched Audio')
plt.show()

# %% [markdown]
# ## SHIFTING AUDIO FILE

# %%
import matplotlib.pyplot as plt

# Assuming you have a function shift() that shifts your audio data
x = shift(data)

plt.figure(figsize=(14, 4))
plt.plot(x)
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.title('Waveform of Shifted Audio')
plt.show()

# %% [markdown]
# ## PITCHING

# %%
import matplotlib.pyplot as plt

# Assuming you have a function pitch() that adjusts the pitch of your audio data
x = pitch(data, sample_rate)

plt.figure(figsize=(14, 4))
plt.plot(x)
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.title('Waveform of Pitch-adjusted Audio')
plt.show()

# %%
def extract_features(data):
    # ZCR
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr)) # stacking horizontally

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel)) # stacking horizontally
    
    return result

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    
    # without augmentation
    res1 = extract_features(data)
    result = np.array(res1)
    
    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2)) # stacking vertically
    
    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3)) # stacking vertically
    
    return result

# %%
X, Y = [], []
for path, emotion in zip(data_path.Path, data_path.Emotions):
    feature = get_features(path)
    for ele in feature:
        X.append(ele)
        # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
        Y.append(emotion)

# %%
len(X), len(Y), data_path.Path.shape
# Out:
# (11901, 11901, (10722,))

# %%
Features = pd.DataFrame(X)
Features['labels'] = Y
Features.to_csv('features.csv', index=False)
Features.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.123485  0.676040  0.691122  0.650269  0.633663  0.657822  0.681000
# 1  0.185859  0.727243  0.708445  0.672316  0.684236  0.718118  0.671005
# 2  0.140520  0.593026  0.653542  0.662359  0.612229  0.622612  0.650427
# 3  0.140641  0.514829  0.537197  0.462284  0.421372  0.371453  0.355751
# 4  0.162883  0.532704  0.563959  0.501462  0.462267  0.415846  0.389004
#
#           7         8         9  ...       153       154       155       156  \
# 0  0.559709  0.509758  0.514564  ...  0.002295  0.001761  0.001271  0.002032
# 1  0.550133  0.538602  0.562830  ...  0.002953  0.002420  0.001963  0.002648
# 2  0.663980  0.503343  0.482931  ...  0.000409  0.000339  0.000327  0.000209
# 3  0.360818  0.484148  0.613376  ...  0.011902  0.020173  0.032610  0.054565
# 4  0.380650  0.504954  0.629777  ...  0.013957  0.022111  0.034899  0.056170
#
#         157       158       159       160       161  labels
# 0  0.002076  0.001977  0.001264  0.000847  0.000211    fear
# 1  0.002864  0.002690  0.002011  0.001523  0.000904    fear
# 2  0.000281  0.000377  0.000337  0.000185  0.000010    fear
# 3  0.036909  0.020285  0.037960  0.023243  0.003520    fear
# 4  0.038739  0.021895  0.039728  0.025611  0.005541    fear
#
# [5 rows x 163 columns]

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
Y.shape
# Out:
# (7734,)

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5800, 162), (5800, 7), (1934, 162), (1934, 7))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5800, 162), (5800, 7), (1934, 162), (1934, 7))

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5800, 162, 1), (5800, 7), (1934, 162, 1), (1934, 7))

# %%
x_train.shape
# Out:
# (5800, 162, 1)

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=7, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 162, 256)       │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 81, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 81, 256)        │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 41, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 41, 128)        │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 21, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 21, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 21, 64)         │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 704)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │        22,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 557,255 (2.13 MB)
#  Trainable params: 557,255 (2.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
x_train.shape,y_train.shape,x_test.shape, y_test.shape
# Out:
# ((5800, 162, 1), (5800, 7), (1934, 162, 1), (1934, 7))

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.00001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.1886 - loss: 1.9045 - val_accuracy: 0.2487 - val_loss: 1.8184 - learning_rate: 0.0010
# Epoch 2/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2297 - loss: 1.8287 - val_accuracy: 0.2932 - val_loss: 1.7770 - learning_rate: 0.0010
# Epoch 3/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2714 - loss: 1.7669 - val_accuracy: 0.3087 - val_loss: 1.7264 - learning_rate: 0.0010
# Epoch 4/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2776 - loss: 1.7423 - val_accuracy: 0.3139 - val_loss: 1.6836 - learning_rate: 0.0010
# Epoch 5/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3074 - loss: 1.6761 - val_accuracy: 0.3402 - val_loss: 1.6325 - learning_rate: 0.0010
# Epoch 6/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3331 - loss: 1.6411 - val_accuracy: 0.3511 - val_loss: 1.5973 - learning_rate: 0.0010
# Epoch 7/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3380 - loss: 1.6275 - val_accuracy: 0.3619 - val_loss: 1.5573 - learning_rate: 0.0010
# Epoch 8/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3568 - loss: 1.5743 - val_accuracy: 0.3666 - val_loss: 1.5570 - learning_rate: 0.0010
# Epoch 9/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3843 - loss: 1.5289 - val_accuracy: 0.3899 - val_loss: 1.5093 - learning_rate: 0.0010
# Epoch 10/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4092 - loss: 1.4840 - val_accuracy: 0.3950 - val_loss: 1.4853 - learning_rate: 0.0010
# Epoch 11/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4163 - loss: 1.4555 - val_accuracy: 0.4307 - val_loss: 1.4428 - learning_rate: 0.0010
# Epoch 12/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4332 - loss: 1.4246 - val_accuracy: 0.4385 - val_loss: 1.4268 - learning_rate: 0.0010
# Epoch 13/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4654 - loss: 1.3668 - val_accuracy: 0.4354 - val_loss: 1.3948 - learning_rate: 0.0010
# Epoch 14/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4552 - loss: 1.3617 - val_accuracy: 0.4519 - val_loss: 1.3881 - learning_rate: 0.0010
# Epoch 15/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4887 - loss: 1.2981 - val_accuracy: 0.4550 - val_loss: 1.3494 - learning_rate: 0.0010
# Epoch 16/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5212 - loss: 1.2384 - val_accuracy: 0.4793 - val_loss: 1.3137 - learning_rate: 0.0010
# Epoch 17/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5211 - loss: 1.2402 - val_accuracy: 0.4690 - val_loss: 1.3343 - learning_rate: 0.0010
# Epoch 18/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5346 - loss: 1.1995 - val_accuracy: 0.4804 - val_loss: 1.3158 - learning_rate: 0.0010
# Epoch 19/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5337 - loss: 1.1936 - val_accuracy: 0.4788 - val_loss: 1.3215 - learning_rate: 0.0010
# Epoch 20/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5464 - loss: 1.1559 - val_accuracy: 0.4912 - val_loss: 1.2922 - learning_rate: 0.0010
# Epoch 21/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5900 - loss: 1.0566 - val_accuracy: 0.5124 - val_loss: 1.2582 - learning_rate: 0.0010
# Epoch 22/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5675 - loss: 1.0782 - val_accuracy: 0.4933 - val_loss: 1.2799 - learning_rate: 0.0010
# Epoch 23/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5844 - loss: 1.0715 - val_accuracy: 0.4969 - val_loss: 1.2971 - learning_rate: 0.0010
# Epoch 24/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5960 - loss: 1.0497 - val_accuracy: 0.5124 - val_loss: 1.2452 - learning_rate: 0.0010
# Epoch 25/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6163 - loss: 0.9927 - val_accuracy: 0.5160 - val_loss: 1.2121 - learning_rate: 0.0010
# Epoch 26/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6397 - loss: 0.9222 - val_accuracy: 0.5310 - val_loss: 1.2809 - learning_rate: 0.0010
# Epoch 27/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6459 - loss: 0.9191 - val_accuracy: 0.5284 - val_loss: 1.2306 - learning_rate: 0.0010
# Epoch 28/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6584 - loss: 0.8940 - val_accuracy: 0.5403 - val_loss: 1.2537 - learning_rate: 0.0010
# Epoch 29/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6701 - loss: 0.8636 - val_accuracy: 0.5465 - val_loss: 1.2635 - learning_rate: 0.0010
# Epoch 30/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6799 - loss: 0.8400 - val_accuracy: 0.5496 - val_loss: 1.2334 - learning_rate: 0.0010
# Epoch 31/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6956 - loss: 0.8129 - val_accuracy: 0.5486 - val_loss: 1.2234 - learning_rate: 0.0010
# Epoch 32/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7065 - loss: 0.7919 - val_accuracy: 0.5558 - val_loss: 1.2593 - learning_rate: 0.0010
# Epoch 33/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7008 - loss: 0.8052 - val_accuracy: 0.5527 - val_loss: 1.2430 - learning_rate: 0.0010
# Epoch 34/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7283 - loss: 0.7445 - val_accuracy: 0.5631 - val_loss: 1.1915 - learning_rate: 0.0010
# Epoch 35/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7048 - loss: 0.7414 - val_accuracy: 0.5626 - val_loss: 1.2804 - learning_rate: 0.0010
# Epoch 36/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7280 - loss: 0.7431 - val_accuracy: 0.5760 - val_loss: 1.2228 - learning_rate: 0.0010
# Epoch 37/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7589 - loss: 0.6541 - val_accuracy: 0.5688 - val_loss: 1.2617 - learning_rate: 0.0010
# Epoch 38/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7522 - loss: 0.6539 - val_accuracy: 0.5853 - val_loss: 1.2935 - learning_rate: 0.0010
# Epoch 39/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7680 - loss: 0.6096 - val_accuracy: 0.5615 - val_loss: 1.2617 - learning_rate: 0.0010
# Epoch 40/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7583 - loss: 0.6504 - val_accuracy: 0.5874 - val_loss: 1.2521 - learning_rate: 0.0010
# Epoch 41/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7666 - loss: 0.6034 - val_accuracy: 0.5703 - val_loss: 1.3642 - learning_rate: 0.0010
# Epoch 42/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7777 - loss: 0.5953 - val_accuracy: 0.5889 - val_loss: 1.2495 - learning_rate: 0.0010
# Epoch 43/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7813 - loss: 0.5765 - val_accuracy: 0.5827 - val_loss: 1.2291 - learning_rate: 0.0010
# Epoch 44/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7994 - loss: 0.5411 - val_accuracy: 0.5993 - val_loss: 1.2526 - learning_rate: 0.0010
# Epoch 45/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8026 - loss: 0.5376 - val_accuracy: 0.5977 - val_loss: 1.3422 - learning_rate: 0.0010
# Epoch 46/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8142 - loss: 0.4995 - val_accuracy: 0.5926 - val_loss: 1.3456 - learning_rate: 0.0010
# Epoch 47/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8146 - loss: 0.5065 - val_accuracy: 0.5967 - val_loss: 1.3109 - learning_rate: 0.0010
# Epoch 48/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8044 - loss: 0.5200 - val_accuracy: 0.5760 - val_loss: 1.3470 - learning_rate: 0.0010
# Epoch 49/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8061 - loss: 0.5316 - val_accuracy: 0.6019 - val_loss: 1.2751 - learning_rate: 0.0010
# Epoch 50/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8231 - loss: 0.4718 - val_accuracy: 0.5920 - val_loss: 1.3957 - learning_rate: 0.0010

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((5800, 162, 1), (5800, 7), (1934, 162, 1), (1934, 7))

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5983 - loss: 1.4475
# Accuracy of our model on test data :  59.20372009277344 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
x_test[0]
# Out:
# array([[ 1.20157838e+00],
#        [ 1.33713872e+00],
#        [ 1.66433077e+00],
#        [ 1.55027652e+00],
#        [ 1.03290424e+00],
#        [ 1.28422904e+00],
#        [ 1.08964374e+00],
#        [ 9.74735393e-01],
#        [ 5.84148803e-01],
#        [ 1.78189239e-01],
#        [ 5.17202121e-01],
#        [ 9.09811912e-01],
#        [ 1.15548396e+00],
#        [ 1.44735682e+00],
#        [-1.55932396e+00],
#        [ 1.02448878e+00],
#        [ 1.27804410e+00],
#        [ 8.63946652e-01],
#        [ 2.35547491e-01],
#        [ 6.33679930e-01],
#        [ 1.11713124e+00],
#        [ 1.19683833e+00],
#        [-4.34855536e-02],
#        [-2.50131862e-01],
#        [ 1.41619409e+00],
#        [-8.85738643e-02],
#        [ 5.52443143e-02],
#        [ 3.53446862e-01],
#        [-6.28601730e-01],
#        [ 6.15911409e-01],
#        [ 2.21007083e-01],
#        [ 7.26591749e-01],
#        [ 8.04281855e-01],
#        [ 3.16644192e-01],
#        [ 7.02981293e-01],
#        [ 9.96606453e-01],
#        [ 7.37006736e-01],
#        [ 5.21939260e-01],
#        [ 5.51005680e-01],
#        [ 2.55296987e-01],
#        [ 2.97040967e-03],
#        [-7.59942788e-03],
#        [ 4.50476169e-02],
#        [-1.87629253e-01],
#        [-4.18266096e-01],
#        [-4.15651933e-01],
#        [-1.10925343e-01],
#        [ 3.73662939e-02],
#        [ 5.33108882e-02],
#        [-1.99578450e-01],
#        [-2.19907059e-01],
#        [-2.64615889e-01],
#        [-2.90708479e-01],
#        [-3.43177844e-01],
#        [-3.29504575e-01],
#        [-3.09708455e-01],
#        [-2.91962135e-01],
#        [-2.51445863e-01],
#        [-2.31286165e-01],
#        [-3.04384435e-02],
#        [ 7.12964470e-02],
#        [ 2.47671109e-01],
#        [ 2.39724703e+00],
#        [ 2.73741025e+00],
#        [-1.33942047e-01],
#        [-2.09339820e-01],
#        [-2.37025820e-01],
#        [-2.57834191e-01],
#        [-2.70493349e-01],
#        [-2.44658998e-01],
#        [-1.30634777e-01],
#        [-1.70486973e-01],
#        [-1.84392279e-01],
#        [-1.84332173e-01],
#        [-1.80702694e-01],
#        [-1.83412612e-01],
#        [-1.86593660e-01],
#        [-1.42702778e-01],
#        [-1.92186269e-01],
#        [-2.28822256e-01],
#        [-2.27996240e-01],
#        [-1.60302795e-01],
#        [-1.63935589e-01],
#        [-1.94681618e-01],
#        [-2.39075887e-01],
#        [-2.13707122e-01],
#        [-1.65665114e-01],
#        [-1.82058765e-01],
#        [-1.74916434e-01],
#        [-1.94650758e-01],
#        [-1.80390563e-01],
#        [-1.46209863e-01],
#        [-2.22024570e-01],
#        [-1.77930973e-01],
#        [-5.53721797e-02],
#        [-5.12432873e-02],
#        [-4.38461396e-02],
#        [ 1.70602918e-01],
#        [ 1.70091937e-01],
#        [ 3.50737906e-01],
#        [ 5.04606547e-01],
#        [ 5.88330448e-01],
#        [ 1.08716231e+00],
#        [ 2.31641605e+00],
#        [ 1.26559543e+00],
#        [ 4.14899510e-01],
#        [ 2.71301516e-01],
#        [ 7.93954237e-02],
#        [ 5.86689572e-01],
#        [ 3.52889592e-01],
#        [ 1.37281226e-01],
#        [ 6.57433266e-02],
#        [-3.13523957e-02],
#        [-1.00844019e-01],
#        [-1.17787278e-01],
#        [-1.43533326e-01],
#        [-1.51143082e-01],
#        [-1.55491514e-01],
#        [-1.70933266e-01],
#        [-1.67329396e-01],
#        [-1.33161193e-01],
#        [-1.08356564e-01],
#        [-7.35070380e-02],
#        [-1.84789083e-02],
#        [ 1.48503024e-01],
#        [ 7.73967053e-01],
#        [ 1.56843004e+00],
#        [ 9.40794906e-01],
#        [ 3.02950770e+00],
#        [ 2.75751361e+00],
#        [ 7.71490485e-01],
#        [ 1.00833100e+00],
#        [ 4.69405610e-01],
#        [ 1.88800719e-01],
#        [ 3.92432617e-03],
#        [-1.41806176e-01],
#        [-1.26669442e-01],
#        [-1.02829623e-01],
#        [-1.00481257e-01],
#        [-6.29021044e-02],
#        [-5.76161812e-02],
#        [-6.54904774e-02],
#        [-5.59391638e-02],
#        [-2.78154543e-02],
#        [-9.45058901e-03],
#        [ 1.36615081e-02],
#        [ 6.76632396e-02],
#        [ 9.34700951e-02],
#        [ 1.00037592e-01],
#        [ 9.10812459e-02],
#        [ 1.15804129e-01],
#        [ 1.59598571e-01],
#        [ 1.22955284e-01],
#        [ 5.31697219e-02],
#        [ 1.24331834e-02],
#        [-1.87064106e-02],
#        [-3.43282192e-02],
#        [-1.33230850e-02],
#        [ 6.41871629e-04],
#        [-2.97073924e-02],
#        [ 1.60033231e-01],
#        [ 8.66487184e-01]])

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0          neutral       neutral
# 1             fear          fear
# 2          neutral           sad
# 3          disgust         happy
# 4            happy         happy
# 5          neutral         happy
# 6          neutral       neutral
# 7              sad       disgust
# 8            happy       neutral
# 9             fear          fear

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
